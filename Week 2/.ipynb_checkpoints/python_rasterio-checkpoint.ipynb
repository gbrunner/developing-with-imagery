# %%
import rasterio
import rasterio.plot
import pyproj
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Rasterio with NAIP on Azure

# %% [markdown]
# ### For some reason this fails the first time...

# %%
print('NAIP on Azure:')
filepath = 'http://naipblobs.blob.core.windows.net/naip/data/v1/2012/states/mo/mo_1m_2012/36089/m_3608901_nw_16_1_20120614.mrf'
with rasterio.open(filepath) as src:
    print(src.profile)
# Out:
# NAIP on Azure:
# {'driver': 'MRF', 'dtype': 'uint8', 'nodata': None, 'width': 6383, 'height': 7711, 'count': 4, 'crs': CRS.from_dict(init='epsg:26916'), 'transform': Affine(1.0, 0.0, 232519.0,
#        0.0, -1.0, 4099381.0), 'blockxsize': 512, 'blockysize': 512, 'tiled': True, 'compress': 'lerc', 'interleave': 'band'}

# %%
num_bands = src.count
pixel_array = np.zeros((num_bands, src.height, src.width))

with rasterio.open(filepath) as src:
    for band_num in range(num_bands):
        print('Reading band number ' + str(band_num+1))
        pixel_array[band_num, :, :] = src.read(band_num+1, out_shape=(1, int(src.height), int(src.width)))
# Out:
# Reading band number 1
# Reading band number 2
# Reading band number 3
# Reading band number 4

# %%
plt.style.use('fivethirtyeight')

plt.figure(figsize=(12, 12), dpi= 96, facecolor='w', edgecolor='k')

fig, ax = plt.subplots(1, num_bands, sharex='col', sharey='row')
fig.set_figheight(16)
fig.set_figwidth(16)

for i in range(num_bands):
    ax[i].imshow(pixel_array[i, :, :]) 
    plt.setp(ax[i],title="Band " + str(i+1))

# %% [markdown]
# ## Rasterio with Landsat on Google

# %%
print('Landsat on Google:')
filepath = 'http://storage.googleapis.com/gcp-public-data-landsat/LC08/01/042/034/LC08_L1TP_042034_20170616_20170629_01_T1/LC08_L1TP_042034_20170616_20170629_01_T1_B4.TIF'
with rasterio.open(filepath) as src:
    print(src.profile)
# Out:
# Landsat on Google:
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 7821, 'height': 7951, 'count': 1, 'crs': CRS.from_dict(init='epsg:32611'), 'transform': Affine(30.0, 0.0, 204285.0,
#        0.0, -30.0, 4268115.0), 'blockxsize': 256, 'blockysize': 256, 'tiled': True, 'compress': 'lzw', 'interleave': 'band'}

# %%
with rasterio.open(filepath) as src:
    image = src.read(1, out_shape=(1, int(src.height), int(src.width)))

    image = image.astype('f4')
    image[image==0] = np.nan

plt.imshow(image)
plt.colorbar()
plt.title('Overview - Band 4 {}'.format(image.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')

# %% [markdown]
# ## Rasterio with Landsat on AWS

# %%
print('Landsat on AWS:')
filepath = 'http://landsat-pds.s3.amazonaws.com/c1/L8/042/034/LC08_L1TP_042034_20170616_20170629_01_T1/LC08_L1TP_042034_20170616_20170629_01_T1_B5.TIF'
with rasterio.open(filepath) as src:
    print(src.profile)
# Out:
# Landsat on AWS:
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 7821, 'height': 7951, 'count': 1, 'crs': CRS.from_dict(init='epsg:32611'), 'transform': Affine(30.0, 0.0, 204285.0,
#        0.0, -30.0, 4268115.0), 'blockxsize': 512, 'blockysize': 512, 'tiled': True, 'compress': 'deflate', 'interleave': 'band'}

# %%
with rasterio.open(filepath) as src:
    image = src.read(1, out_shape=(1, int(src.height), int(src.width)))

    image = image.astype('f4')
    image[image==0] = np.nan

plt.imshow(image)
plt.colorbar()
plt.title('Overview - Band 5 {}'.format(image.shape))
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Text(0, 0.5, 'Row #')
